# %% [markdown]
# Intro text about FHIR Bulk Data, what we're going to do in this workshop, etc.
#
# http://hl7.org/fhir/uv/bulkdata/index.html
#
# http://www.hl7.org/fhir/smart-app-launch/backend-services.html
#
# The goal of this workshop is to connect to the SMART Bulk Data Server and fetch a set of sample patient data.
# While libraries like FHIR-PYrate https://github.com/UMEssen/FHIR-PYrate allow you to fetch data from a server and parse it directly into a DataFrame, these libraries generally do not support FHIR Bulk Data. This workshop will step through the process of building up functions to fetch Bulk Data and convert it into DataFrames.

# %% [markdown]
# The FHIR Bulk Data specification uses SMART Backend Authorization to connect. The basic idea of SMART Backend Authorization is that registered clients make a signed request to a token endpoint to receive a Bearer token, which is then used for subsequent calls to the FHIR server.
#
# In practice, client registration is likely to happen as a separate one-time event performed manually. The SMART Backend Auth specification does not define an API for registration.
#
# For this workshop, we are connecting to the SMART Bulk Data Server which allows clients to "register" using either a JWKS URL or by raw JWKS. ("registration" in this case is not stored on the server, instead they provide a base URL where that "registration" is stored as state in the URL and clientID).
# For convenience, the SMART Bulk Data Server launch page allows users to generate a once-off JWKS to use for testing. For production usage, clients must generate their own certificates and JWKS and keep the private key private. In this workshop we use a JWKS generated by the launch page with algorithm "RS384".
#
# IMPORTANT: this workshop largely skips error handling and stays on the "happy path" for brevity and readability. We strongly recommend reviewing the specifications and adding better error handling before using any of this code in a production environment.

# %%
# First define our credentials

client_id = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6InJlZ2lzdHJhdGlvbi10b2tlbiJ9.....OdAI3mUiBsEIF1ViZRyqOb6gpEg3HOxPjSB9kwf9R8w'

private_key = """-----BEGIN RSA PRIVATE KEY-----

eoy1i+FsLW6dhoqrizD9ma+tGkXaiPT9+kGbrNlAxUZSlW5NkysW
-----END RSA PRIVATE KEY-----
"""

key_id = "09a2ddf39ceef0df045d7f4e396c7851"

# And server endpoint
server_url = 'https://bulk-data.smarthealthit.org/eyJlcnIiOiIiLCJwYWdlIjoxMDAwMCwiZHVyIjoxMCwidGx0IjoxNSwibSI6MSwic3R1Ijo0LCJkZWwiOjB9/fhir'

# %%
# we use the requests library to make all HTTP requests
import requests

# and use a Session, in case we need to persist common settings such as proxy or SSL configuration
session = requests.Session()

from urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(category=InsecureRequestWarning)
session.verify = False

# %%
# Let's start by confirming we can even hit the server with the metadata endpoint
r = session.get(f'{server_url}/metadata')
metadata = r.json()

metadata
# Out:
# {'resourceType': 'CapabilityStatement',
#  'status': 'active',
#  'date': '2023-05-18T13:11:36+00:00',
#  'publisher': "Boston Children's Hospital",
#  'kind': 'instance',
#  'instantiates': ['http://hl7.org/fhir/uv/bulkdata/CapabilityStatement/bulk-data'],
#  'software': {'name': 'SMART Sample Bulk Data Server', 'version': '2.1.1'},
#  'implementation': {'description': 'SMART Sample Bulk Data Server'},
#  'fhirVersion': '4.0.1',
#  'acceptUnknown': 'extensions',
#  'format': ['json'],
#  'rest': [{'mode': 'server',
#    'security': {'extension': [{'url': 'http://fhir-registry.smarthealthit.org/StructureDefinition/oauth-uris',
#       'extension': [{'url': 'token',
#         'valueUri': 'https://bulk-data.smarthealthit.org/auth/token'},
#        {'url': 'register',
#         'valueUri': 'https://bulk-data.smarthealthit.org/auth/register'}]}],
#     'service': [{'coding': [{'system': 'http://hl7.org/fhir/restful-security-service',
#         'code': 'SMART-on-FHIR',
#         'display': 'SMART-on-FHIR'}],
#       'text': 'OAuth2 using SMART-on-FHIR profile (see http://docs.smarthealthit.org)'}]},
#    'resource': [{'type': 'Patient',
#      'operation': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#          'valueCode': 'SHOULD'}],
#        'name': 'patient-export',
#        'definition': 'http://hl7.org/fhir/uv/bulkdata/OperationDefinition/patient-export'}]},
#     {'type': 'Group',
#      'operation': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#          'valueCode': 'SHOULD'}],
#        'name': 'group-export',
#        'definition': 'http://hl7.org/fhir/uv/bulkdata/OperationDefinition/group-export'}]},
#     {'type': 'OperationDefinition',
#      'profile': {'reference': 'http://hl7.org/fhir/Profile/OperationDefinition'},
#      'interaction': [{'code': 'read'}],
#      'searchParam': []}],
#    'operation': [{'name': 'get-resource-counts',
#      'definition': 'OperationDefinition/-s-get-resource-counts'},
#     {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#        'valueCode': 'SHOULD'}],
#      'name': 'export',
#      'definition': 'http://hl7.org/fhir/uv/bulkdata/OperationDefinition/export'}]}]}

# %%
# For SMART Backend Auth, the token endpoint is published at .well-known/smart-configuration
r = session.get(f'{server_url}/.well-known/smart-configuration')
smart_config = r.json()

smart_config
# Out:
# {'token_endpoint': 'https://bulk-data.smarthealthit.org/auth/token',
#  'registration_endpoint': 'https://bulk-data.smarthealthit.org/auth/register',
#  'token_endpoint_auth_methods_supported': ['private_key_jwt'],
#  'token_endpoint_auth_signing_alg_values_supported': ['HS256',
#   'HS384',
#   'HS512',
#   'RS256',
#   'RS384',
#   'RS512',
#   'ES256',
#   'ES384',
#   'ES512',
#   'PS256',
#   'PS384',
#   'PS512'],
#  'scopes_supported': ['system/*.rs',
#   'system/Patient.rs',
#   'system/Encounter.rs',
#   'system/Condition.rs',
#   'system/Claim.rs',
#   'system/ExplanationOfBenefit.rs',
#   'system/Observation.rs',
#   'system/Immunization.rs',
#   'system/DiagnosticReport.rs',
#   'system/Procedure.rs',
#   'system/CareTeam.rs',
#   'system/CarePlan.rs',
#   'system/MedicationRequest.rs',
#   'system/AllergyIntolerance.rs',
#   'system/Device.rs',
#   'system/ImagingStudy.rs',
#   'system/Organization.rs',
#   'system/Practitioner.rs',
#   'system/DocumentReference.rs',
#   'system/Group.rs',
#   'system/*.read',
#   'system/Patient.read',
#   'system/Encounter.read',
#   'system/Condition.read',
#   'system/Claim.read',
#   'system/ExplanationOfBenefit.read',
#   'system/Observation.read',
#   'system/Immunization.read',
#   'system/DiagnosticReport.read',
#   'system/Procedure.read',
#   'system/CareTeam.read',
#   'system/CarePlan.read',
#   'system/MedicationRequest.read',
#   'system/AllergyIntolerance.read',
#   'system/Device.read',
#   'system/ImagingStudy.read',
#   'system/Organization.read',
#   'system/Practitioner.read',
#   'system/DocumentReference.read',
#   'system/Group.read'],
#  'capabilities': ['permission-v2',
#   'permission-v1',
#   'client-confidential-asymmetric']}

# %%
# There are a number of important fields here, but for now the one we care most about is the token_endpoint
token_endpoint = smart_config['token_endpoint']

# %%
# Now to get a token, we create a JWT client assertion as follows:
import jwt
import datetime

assertion = jwt.encode({
        'iss': client_id,
        'sub': client_id,
        'aud': token_endpoint,
        'exp': int((datetime.datetime.now() + datetime.timedelta(minutes=5)).timestamp())
}, private_key, algorithm='RS384',
headers={"kid": key_id}) # kid required for smart bulk data server


# And post it to the token endpont
r = session.post(token_endpoint, data={
    'scope': 'system/*.read',
    'grant_type': 'client_credentials',
    'client_assertion_type': 'urn:ietf:params:oauth:client-assertion-type:jwt-bearer',
    'client_assertion': assertion
})

token_response = r.json()

token_response
# Out:
# {'token_type': 'bearer',
#  'scope': 'system/*.read',
#  'expires_in': 299,
#  'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYmVhcmVyIiwic2NvcGUiOiJzeXN0ZW0vKi5yZWFkIiwiZXhwaXJlc19pbiI6Mjk5LCJpYXQiOjE2ODQ0NDQ5NDMsImV4cCI6MTY4NDQ0NTI0Mn0.Zzdne5i3oO0KBFnsjhfMyImCldFoWXRbtM78UptC-5s'}

# %%
# Two important fields we need to keep track of are the token itself, and the expire time. 
# Tokens are only valid for a certain amount of time, and once they expire
# we will need to fetch a new one via the same process as above.
# 'expires_in' is in seconds from the current time. 

token = token_response['access_token']
expire_time = datetime.datetime.now() + datetime.timedelta(seconds=token_response['expires_in'])

# %%
# Now to make this easier for ourselves, let's package this up into a function that we can call 

def get_token():
    global token, expire_time
    if datetime.datetime.now() < expire_time:
        # the existing token is still valid so 
        return token
    
    assertion = jwt.encode({
            'iss': client_id,
            'sub': client_id,
            'aud': token_endpoint,
            'exp': int((datetime.datetime.now() + datetime.timedelta(minutes=5)).timestamp())
    }, private_key, algorithm='RS384',
    headers={"kid": key_id})

    r = session.post(token_endpoint, data={
        'scope': 'system/*.read',
        'grant_type': 'client_credentials',
        'client_assertion_type': 'urn:ietf:params:oauth:client-assertion-type:jwt-bearer',
        'client_assertion': assertion
    })

    token_response = r.json()
    token = token_response['access_token']
    expire_time = datetime.datetime.now() + datetime.timedelta(seconds=token_response['expires_in'])
    
    return token

# now we can reference get_token() and it will automatically fetch a new one whenever needed

# %%
# Now we make the export request
r = session.get(f'{server_url}/Patient/$export?_type=Patient,Condition', headers={'Authorization': f'Bearer {get_token()}', 'Accept': 'application/fhir+json', 'Prefer': 'respond-async'})

r.headers
# Out:
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'Content-Location': 'https://bulk-data.smarthealthit.org/fhir/bulkstatus/06771732fc08e2f250431a3a8d9fd7f2', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '644', 'Etag': 'W/"284-AothQCy6VN/EvjChVMq1OgdnwQA"', 'Date': 'Thu, 18 May 2023 21:22:23 GMT', 'Via': '1.1 vegur'}

# %%
check_url = r.headers['Content-Location']
check_url
# Out:
# 'https://bulk-data.smarthealthit.org/fhir/bulkstatus/06771732fc08e2f250431a3a8d9fd7f2'

# %%
# Now we check the status in a loop

from time import sleep

while True:
    r = session.get(check_url, headers={'Authorization': f'Bearer {get_token()}', 'Accept': 'application/fhir+json'})

    # There are three possible options here: http://hl7.org/fhir/uv/bulkdata/export.html#bulk-data-status-request
    # Error = 4xx or 5xx status code
    # In-Progress = 202
    # Complete = 200

    if r.status_code == 200:
        # complete
        response = r.json()
        print(response)
        break

    elif r.status_code == 202:
        # in progress
        print(r.headers)
        
        delay = r.headers['Retry-After']
        
        print(f"Sleeping {delay} seconds before retrying")
        sleep(int(delay))

    else:
        # error
        print(r.text)

        break
# Out:
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Progress': '0% complete, currenly processing Patient resources', 'Retry-After': '2', 'Date': 'Thu, 18 May 2023 21:22:23 GMT', 'Content-Length': '0', 'Via': '1.1 vegur'}
# Sleeping 2 seconds before retrying
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Progress': '21% complete, currenly processing Patient resources', 'Retry-After': '2', 'Date': 'Thu, 18 May 2023 21:22:25 GMT', 'Content-Length': '0', 'Via': '1.1 vegur'}
# Sleeping 2 seconds before retrying
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Progress': '41% complete, currenly processing Patient resources', 'Retry-After': '2', 'Date': 'Thu, 18 May 2023 21:22:27 GMT', 'Content-Length': '0', 'Via': '1.1 vegur'}
# Sleeping 2 seconds before retrying
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Progress': '61% complete, currenly processing Patient resources', 'Retry-After': '2', 'Date': 'Thu, 18 May 2023 21:22:29 GMT', 'Content-Length': '0', 'Via': '1.1 vegur'}
# Sleeping 2 seconds before retrying
# {'Server': 'Cowboy', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Progress': '82% complete, currenly processing Patient resources', 'Retry-After': '2', 'Date': 'Thu, 18 May 2023 21:22:31 GMT', 'Content-Length': '0', 'Via': '1.1 vegur'}
# Sleeping 2 seconds before retrying
# {'transactionTime': '1684444943430', 'request': 'https://bulk-data.smarthealthit.org/eyJlcnIiOiIiLCJwYWdlIjoxMDAwMCwiZHVyIjoxMCwidGx0IjoxNSwibSI6MSwic3R1Ijo0LCJkZWwiOjB9/fhir/Patient/$export?_type=Patient,Condition', 'requiresAccessToken': True, 'output': [{'type': 'Condition', 'count': 639, 'url': 'https://bulk-data.smarthealthit.org/eyJpZCI6IjA2NzcxNzMyZmMwOGUyZjI1MDQzMWEzYThkOWZkN2YyIiwib2Zmc2V0IjowLCJsaW1pdCI6NjM5LCJzZWN1cmUiOnRydWV9/fhir/bulkfiles/1.Condition.ndjson'}, {'type': 'Patient', 'count': 100, 'url': 'https://bulk-data.smarthealthit.org/eyJpZCI6IjA2NzcxNzMyZmMwOGUyZjI1MDQzMWEzYThkOWZkN2YyIiwib2Zmc2V0IjowLCJsaW1pdCI6MTAwLCJzZWN1cmUiOnRydWV9/fhir/bulkfiles/1.Patient.ndjson'}], 'deleted': [], 'error': []}

# %%
output_files = response['output']
output_files
# Out:
# [{'type': 'Condition',
#   'count': 639,
#   'url': 'https://bulk-data.smarthealthit.org/eyJpZCI6IjA2NzcxNzMyZmMwOGUyZjI1MDQzMWEzYThkOWZkN2YyIiwib2Zmc2V0IjowLCJsaW1pdCI6NjM5LCJzZWN1cmUiOnRydWV9/fhir/bulkfiles/1.Condition.ndjson'},
#  {'type': 'Patient',
#   'count': 100,
#   'url': 'https://bulk-data.smarthealthit.org/eyJpZCI6IjA2NzcxNzMyZmMwOGUyZjI1MDQzMWEzYThkOWZkN2YyIiwib2Zmc2V0IjowLCJsaW1pdCI6MTAwLCJzZWN1cmUiOnRydWV9/fhir/bulkfiles/1.Patient.ndjson'}]

# %%
# so the reponse points us to one or more ndjson files per resource type
# Now we can loop through the list and download each one
# Each file is an NDJSON (Newline Delimited JSON) so that's one resource per line.
# For starters we'll keep a dict of { resourceType: [resources,...]}
import json

resources_by_type = {}

for output_file in output_files:
    download_url = output_file['url']
    resource_type = output_file['type']
    
    r = session.get(download_url, headers={'Authorization': f'Bearer {get_token()}', 'Accept': 'application/fhir+json'})
                                                   
    ndjson = r.text.strip()
    
    if resource_type not in resources_by_type:
        resources_by_type[resource_type] = []
    
    for line in ndjson.split('\n'):
        resource = json.loads(line)
        resources_by_type[resource_type].append(resource)
        

resources_by_type
# Out:
# {'Condition': [{'resourceType': 'Condition',
#    'id': 'a5a38601-b6fe-46b4-a67e-cde9d5957dde',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '40055000',
#       'display': 'Chronic sinusitis (disorder)'}],
#     'text': 'Chronic sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/17b801ac-58e3-4f6b-8b48-8e33f3a36086'},
#    'onsetDateTime': '1985-06-18T17:30:49-04:00',
#    'recordedDate': '1985-06-18T17:30:49-04:00'},
#   {'resourceType': 'Condition',
#    'id': '8f818ad4-c292-47e8-8d99-c4c54174b671',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '162864005',
#       'display': 'Body mass index 30+ - obesity (finding)'}],
#     'text': 'Body mass index 30+ - obesity (finding)'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/0953dd44-90bb-4805-badd-169a761a6ab3'},
#    'onsetDateTime': '2005-01-19T16:30:49-05:00',
#    'recordedDate': '2005-01-19T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '65d9d5f2-a772-4586-932f-df1f2ce1a863',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '15777000',
#       'display': 'Prediabetes'}],
#     'text': 'Prediabetes'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/d4e1370a-a679-4570-a3dc-e4f7ac847512'},
#    'onsetDateTime': '2013-02-06T16:30:49-05:00',
#    'recordedDate': '2013-02-06T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '77ac8342-6950-4302-a303-efba12e06785',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '68496003',
#       'display': 'Polyp of colon'}],
#     'text': 'Polyp of colon'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/58ad433b-3707-4d40-9b63-2a803b4913bd'},
#    'onsetDateTime': '2015-01-14T16:30:49-05:00',
#    'abatementDateTime': '2017-05-03T17:30:49-04:00',
#    'recordedDate': '2015-01-14T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '6514ab0c-bc64-4e1b-aa61-b97d27d72bc7',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '271737000',
#       'display': 'Anemia (disorder)'}],
#     'text': 'Anemia (disorder)'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/58ad433b-3707-4d40-9b63-2a803b4913bd'},
#    'onsetDateTime': '2015-01-14T16:30:49-05:00',
#    'recordedDate': '2015-01-14T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '8fe237c0-8483-492a-a819-2ee5188027bf',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '713197008',
#       'display': 'Recurrent rectal polyp'}],
#     'text': 'Recurrent rectal polyp'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/16f4675c-db9c-4de1-9e7c-daa74250f575'},
#    'onsetDateTime': '2016-01-09T16:30:49-05:00',
#    'abatementDateTime': '2017-05-03T17:30:49-04:00',
#    'recordedDate': '2016-01-09T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '5d783da9-a172-4750-a910-1af806b89cef',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '10509002',
#       'display': 'Acute bronchitis (disorder)'}],
#     'text': 'Acute bronchitis (disorder)'},
#    'subject': {'reference': 'Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2'},
#    'encounter': {'reference': 'Encounter/495bd72e-fdde-44b7-acbc-8ccdb5d7887b'},
#    'onsetDateTime': '2017-11-25T16:30:49-05:00',
#    'abatementDateTime': '2017-12-09T16:30:49-05:00',
#    'recordedDate': '2017-11-25T16:30:49-05:00'},
#   {'resourceType': 'Condition',
#    'id': '33ed785d-01d0-4a52-946e-60f04a957106',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '40055000',
#       'display': 'Chronic sinusitis (disorder)'}],
#     'text': 'Chronic sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/701a8dbd-c274-410f-8ed0-39748a3d70e8'},
#    'onsetDateTime': '1972-02-03T16:48:38-05:00',
#    'recordedDate': '1972-02-03T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': '0b32d7c5-581e-45f3-bf8b-22fbbefd7618',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '128613002',
#       'display': 'Seizure disorder'}],
#     'text': 'Seizure disorder'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/93cc5f38-fe83-4ef2-b895-810d70395d09'},
#    'onsetDateTime': '1984-04-01T16:48:38-05:00',
#    'recordedDate': '1984-04-01T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'ee3529f2-d48b-4c1d-9901-6672772c0cee',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '703151001',
#       'display': 'History of single seizure (situation)'}],
#     'text': 'History of single seizure (situation)'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/93cc5f38-fe83-4ef2-b895-810d70395d09'},
#    'onsetDateTime': '1984-04-01T16:48:38-05:00',
#    'recordedDate': '1984-04-01T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'd3dbfce5-c2c5-43b3-9ad3-9cb4b6e62d98',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '15777000',
#       'display': 'Prediabetes'}],
#     'text': 'Prediabetes'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/3606c6a2-6ef9-4a3a-a929-c4534a58a3ff'},
#    'onsetDateTime': '1996-06-10T17:48:38-04:00',
#    'recordedDate': '1996-06-10T17:48:38-04:00'},
#   {'resourceType': 'Condition',
#    'id': '02f208e8-ed4a-4395-a6c3-892b576d964a',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '271737000',
#       'display': 'Anemia (disorder)'}],
#     'text': 'Anemia (disorder)'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/3606c6a2-6ef9-4a3a-a929-c4534a58a3ff'},
#    'onsetDateTime': '1996-06-10T17:48:38-04:00',
#    'recordedDate': '1996-06-10T17:48:38-04:00'},
#   {'resourceType': 'Condition',
#    'id': '649dcebb-2cdf-4543-8fb2-1b72b6a4537e',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '195662009',
#       'display': 'Acute viral pharyngitis (disorder)'}],
#     'text': 'Acute viral pharyngitis (disorder)'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/4e0614a0-b979-44c9-a9af-f340cb88e4b5'},
#    'onsetDateTime': '2015-01-08T16:48:38-05:00',
#    'abatementDateTime': '2015-01-19T16:48:38-05:00',
#    'recordedDate': '2015-01-08T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': '2baea607-a1e0-41bc-b201-982f925cedaa',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '403190006',
#       'display': 'First degree burn'}],
#     'text': 'First degree burn'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/e9c98d08-8ec2-4661-899e-1f6ffecf1f0c'},
#    'onsetDateTime': '2015-02-21T16:48:38-05:00',
#    'abatementDateTime': '2015-03-28T17:48:38-04:00',
#    'recordedDate': '2015-02-21T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': '40caf4bc-0271-400c-97d5-30cfd7158767',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '444814009',
#       'display': 'Viral sinusitis (disorder)'}],
#     'text': 'Viral sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/58c297c4-d684-4677-8024-01131d93835e'},
#    'encounter': {'reference': 'Encounter/653ccc87-1197-4dbc-81c6-1fbaf6a38874'},
#    'onsetDateTime': '2020-02-01T16:48:38-05:00',
#    'abatementDateTime': '2020-02-15T16:48:38-05:00',
#    'recordedDate': '2020-02-01T16:48:38-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'd47c4a8b-852d-44b8-ab1d-2dad1beea148',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '40055000',
#       'display': 'Chronic sinusitis (disorder)'}],
#     'text': 'Chronic sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/7276bd69-20bf-4b0c-b3a3-b7f9a47324fd'},
#    'onsetDateTime': '1947-12-15T17:45:58-05:00',
#    'recordedDate': '1947-12-15T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '9b763667-2ba6-4d73-9f2e-8770798a2326',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '410429000',
#       'display': 'Cardiac Arrest'}],
#     'text': 'Cardiac Arrest'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/a4f646bc-1255-4098-8113-ea3f1e89a9b3'},
#    'onsetDateTime': '1949-05-07T18:45:58-04:00',
#    'recordedDate': '1949-05-07T18:45:58-04:00'},
#   {'resourceType': 'Condition',
#    'id': '8f22c246-2a37-4573-b23f-d0420b02285f',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '429007001',
#       'display': 'History of cardiac arrest (situation)'}],
#     'text': 'History of cardiac arrest (situation)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/a4f646bc-1255-4098-8113-ea3f1e89a9b3'},
#    'onsetDateTime': '1949-05-07T18:45:58-04:00',
#    'recordedDate': '1949-05-07T18:45:58-04:00'},
#   {'resourceType': 'Condition',
#    'id': '54b9268a-a4c5-4549-9aaf-9452671fe79b',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '87433001',
#       'display': 'Pulmonary emphysema (disorder)'}],
#     'text': 'Pulmonary emphysema (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/91c4fe0c-fe62-4e12-8c59-6737db65613e'},
#    'onsetDateTime': '1963-03-30T17:45:58-05:00',
#    'recordedDate': '1963-03-30T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'ea59cdd8-3798-46bc-86f5-bbddfd150a84',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '64859006',
#       'display': 'Osteoporosis (disorder)'}],
#     'text': 'Osteoporosis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/5c48e02a-57d8-4dc8-9c2d-7eb9953a485f'},
#    'onsetDateTime': '2003-11-15T17:45:58-05:00',
#    'recordedDate': '2003-11-15T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '1e9b6e72-e59b-49ac-8ade-4bc1bb88012f',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '10509002',
#       'display': 'Acute bronchitis (disorder)'}],
#     'text': 'Acute bronchitis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/74c53fe5-b106-4660-b675-6c580f31f114'},
#    'onsetDateTime': '2010-11-13T17:45:58-05:00',
#    'abatementDateTime': '2010-11-20T17:45:58-05:00',
#    'recordedDate': '2010-11-13T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '26720b05-ffde-447f-b738-53293e20e727',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '65966004',
#       'display': 'Fracture of forearm'}],
#     'text': 'Fracture of forearm'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/02b3780f-b356-401d-a2e9-db16e295d211'},
#    'onsetDateTime': '2010-12-20T17:45:58-05:00',
#    'abatementDateTime': '2011-03-20T18:45:58-04:00',
#    'recordedDate': '2010-12-20T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '790163ad-1e4b-4c3a-bd35-5f5a930911ec',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '443165006',
#       'display': 'Pathological fracture due to osteoporosis (disorder)'}],
#     'text': 'Pathological fracture due to osteoporosis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/02b3780f-b356-401d-a2e9-db16e295d211'},
#    'onsetDateTime': '2010-12-20T17:45:58-05:00',
#    'abatementDateTime': '2011-03-20T18:45:58-04:00',
#    'recordedDate': '2010-12-20T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '4c7f926b-e6b1-4bf2-908d-9ea1cc8350f9',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '444814009',
#       'display': 'Viral sinusitis (disorder)'}],
#     'text': 'Viral sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/0127fd3e-db6d-47a2-bb1e-f74cab700297'},
#    'onsetDateTime': '2015-07-23T18:45:58-04:00',
#    'abatementDateTime': '2015-08-13T18:45:58-04:00',
#    'recordedDate': '2015-07-23T18:45:58-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'fc31d9ab-cc33-4b19-9e38-538fe3e3128a',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '49436004',
#       'display': 'Atrial Fibrillation'}],
#     'text': 'Atrial Fibrillation'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/ca70bca2-fdd6-402d-8b56-b50bba889238'},
#    'onsetDateTime': '2018-02-03T17:45:58-05:00',
#    'recordedDate': '2018-02-03T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'cd515f64-aabb-49ce-8d6d-c7bdb26d5320',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '65966004',
#       'display': 'Fracture of forearm'}],
#     'text': 'Fracture of forearm'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/c2a051f4-9879-4974-b825-bae70277e9f6'},
#    'onsetDateTime': '2018-11-08T17:45:58-05:00',
#    'abatementDateTime': '2018-12-08T17:45:58-05:00',
#    'recordedDate': '2018-11-08T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'f1137c21-3192-47b2-9f08-6d43787bcfcf',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '443165006',
#       'display': 'Pathological fracture due to osteoporosis (disorder)'}],
#     'text': 'Pathological fracture due to osteoporosis (disorder)'},
#    'subject': {'reference': 'Patient/538a9a4e-8437-47d3-8c01-1a17dca8f0be'},
#    'encounter': {'reference': 'Encounter/c2a051f4-9879-4974-b825-bae70277e9f6'},
#    'onsetDateTime': '2018-11-08T17:45:58-05:00',
#    'abatementDateTime': '2018-12-08T17:45:58-05:00',
#    'recordedDate': '2018-11-08T17:45:58-05:00'},
#   {'resourceType': 'Condition',
#    'id': '853bfd03-cd3d-4c58-8569-59c753b375cf',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '301011002',
#       'display': 'Escherichia coli urinary tract infection'}],
#     'text': 'Escherichia coli urinary tract infection'},
#    'subject': {'reference': 'Patient/c6c60742-8694-46e4-bb42-b00bf6d8b536'},
#    'encounter': {'reference': 'Encounter/7e6aff01-1aa6-4c47-b663-5fddb8c694fb'},
#    'onsetDateTime': '2012-10-15T06:09:55-04:00',
#    'abatementDateTime': '2012-12-06T05:09:55-05:00',
#    'recordedDate': '2012-10-15T06:09:55-04:00'},
#   {'resourceType': 'Condition',
#    'id': '8d986b2a-c04b-4768-bc21-5e5f6c66e200',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '195662009',
#       'display': 'Acute viral pharyngitis (disorder)'}],
#     'text': 'Acute viral pharyngitis (disorder)'},
#    'subject': {'reference': 'Patient/c6c60742-8694-46e4-bb42-b00bf6d8b536'},
#    'encounter': {'reference': 'Encounter/3eec6c22-3936-4270-ad74-7de2db6a9167'},
#    'onsetDateTime': '2013-11-21T05:09:55-05:00',
#    'abatementDateTime': '2013-11-29T05:09:55-05:00',
#    'recordedDate': '2013-11-21T05:09:55-05:00'},
#   {'resourceType': 'Condition',
#    'id': '42d116ab-164d-4048-a972-974c27d9c5af',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '195662009',
#       'display': 'Acute viral pharyngitis (disorder)'}],
#     'text': 'Acute viral pharyngitis (disorder)'},
#    'subject': {'reference': 'Patient/c6c60742-8694-46e4-bb42-b00bf6d8b536'},
#    'encounter': {'reference': 'Encounter/6e23a9d6-dcc1-4a0b-9096-c022cd7e332f'},
#    'onsetDateTime': '2014-03-01T05:09:55-05:00',
#    'abatementDateTime': '2014-03-12T06:09:55-04:00',
#    'recordedDate': '2014-03-01T05:09:55-05:00'},
#   {'resourceType': 'Condition',
#    'id': '228ed0ab-ca0a-4bdf-81f7-49c0b447ddf0',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '72892002',
#       'display': 'Normal pregnancy'}],
#     'text': 'Normal pregnancy'},
#    'subject': {'reference': 'Patient/c6c60742-8694-46e4-bb42-b00bf6d8b536'},
#    'encounter': {'reference': 'Encounter/f90e973c-2b70-46c5-8196-204443174d97'},
#    'onsetDateTime': '2014-06-18T06:09:55-04:00',
#    'abatementDateTime': '2015-01-21T05:09:55-05:00',
#    'recordedDate': '2014-06-18T06:09:55-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'ae8aedf6-73f0-4a2d-b124-2a574f8bb0b1',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '15777000',
#       'display': 'Prediabetes'}],
#     'text': 'Prediabetes'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/7dbeb310-bd64-43a4-b795-f6642bfae028'},
#    'onsetDateTime': '1982-07-10T03:52:44-04:00',
#    'recordedDate': '1982-07-10T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'baeacb8a-6482-43c6-8d51-cae1bd3b5b04',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '19169002',
#       'display': 'Miscarriage in first trimester'}],
#     'text': 'Miscarriage in first trimester'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/089bb383-0136-4a15-b14c-32fca7f9dc4a'},
#    'onsetDateTime': '1988-08-20T03:52:44-04:00',
#    'recordedDate': '1988-08-20T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'c58c1bce-5f11-43ab-bdad-f5b357607c6d',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '49436004',
#       'display': 'Atrial Fibrillation'}],
#     'text': 'Atrial Fibrillation'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/b5c2cd23-9823-4ce1-85a1-19de808d13e3'},
#    'onsetDateTime': '1990-07-28T03:52:44-04:00',
#    'recordedDate': '1990-07-28T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'fcb3061a-8834-477c-a11f-6fbb0c125bbd',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '53741008',
#       'display': 'Coronary Heart Disease'}],
#     'text': 'Coronary Heart Disease'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/34d5c00a-e7d6-4764-8ced-38fa222b2df2'},
#    'onsetDateTime': '1998-09-12T03:52:44-04:00',
#    'recordedDate': '1998-09-12T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': '4c35a7c2-d1b8-4035-ba73-66ecd24d6874',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '64859006',
#       'display': 'Osteoporosis (disorder)'}],
#     'text': 'Osteoporosis (disorder)'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/9fddfcd5-2653-4e10-b3e9-6ff63b9fccca'},
#    'onsetDateTime': '2002-10-05T03:52:44-04:00',
#    'recordedDate': '2002-10-05T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': '89161905-259c-49fe-9243-8708775ca424',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '201834006',
#       'display': 'Localized, primary osteoarthritis of the hand'}],
#     'text': 'Localized, primary osteoarthritis of the hand'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/39a64bfe-3b58-42e2-a8cb-24796d387883'},
#    'onsetDateTime': '2004-06-18T03:52:44-04:00',
#    'recordedDate': '2004-06-18T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': '83ff455d-611e-41f0-900f-b7d386ba3789',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '283371005',
#       'display': 'Laceration of forearm'}],
#     'text': 'Laceration of forearm'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/087252aa-afe9-45c9-bccf-1f3daf94d328'},
#    'onsetDateTime': '2011-03-09T02:52:44-05:00',
#    'abatementDateTime': '2011-03-23T03:52:44-04:00',
#    'recordedDate': '2011-03-09T02:52:44-05:00'},
#   {'resourceType': 'Condition',
#    'id': '5e736cd8-5a87-4845-b94e-3c691fb14acf',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '444814009',
#       'display': 'Viral sinusitis (disorder)'}],
#     'text': 'Viral sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/2b53e34c-cc33-4910-b360-1d8e34527501'},
#    'onsetDateTime': '2019-03-18T03:52:44-04:00',
#    'abatementDateTime': '2019-03-25T03:52:44-04:00',
#    'recordedDate': '2019-03-18T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': '299f7aa9-acd0-4017-b5ee-902632330c8f',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '195662009',
#       'display': 'Acute viral pharyngitis (disorder)'}],
#     'text': 'Acute viral pharyngitis (disorder)'},
#    'subject': {'reference': 'Patient/fbfec681-d357-4b28-b1d2-5db6434c7846'},
#    'encounter': {'reference': 'Encounter/aea6b86b-dc60-4e43-9de3-c46b916ef32b'},
#    'onsetDateTime': '2020-04-06T03:52:44-04:00',
#    'abatementDateTime': '2020-04-13T03:52:44-04:00',
#    'recordedDate': '2020-04-06T03:52:44-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'fe778475-12dc-4004-aebc-fa62473ff774',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '15777000',
#       'display': 'Prediabetes'}],
#     'text': 'Prediabetes'},
#    'subject': {'reference': 'Patient/beb1b2a4-9198-462f-ae9d-972f173bd2b1'},
#    'encounter': {'reference': 'Encounter/d87fb0a9-6755-4e16-92f9-2392146696d4'},
#    'onsetDateTime': '1977-11-23T02:11:45-05:00',
#    'recordedDate': '1977-11-23T02:11:45-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'daaa1c32-5692-45bb-b967-973df28f25ac',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '271737000',
#       'display': 'Anemia (disorder)'}],
#     'text': 'Anemia (disorder)'},
#    'subject': {'reference': 'Patient/beb1b2a4-9198-462f-ae9d-972f173bd2b1'},
#    'encounter': {'reference': 'Encounter/d87fb0a9-6755-4e16-92f9-2392146696d4'},
#    'onsetDateTime': '1977-11-23T02:11:45-05:00',
#    'recordedDate': '1977-11-23T02:11:45-05:00'},
#   {'resourceType': 'Condition',
#    'id': '6edaba7d-097b-4ede-965e-8884e9da85c8',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '49436004',
#       'display': 'Atrial Fibrillation'}],
#     'text': 'Atrial Fibrillation'},
#    'subject': {'reference': 'Patient/beb1b2a4-9198-462f-ae9d-972f173bd2b1'},
#    'encounter': {'reference': 'Encounter/f8b0c365-7927-4c53-b906-8abb0face173'},
#    'onsetDateTime': '2008-09-24T03:11:45-04:00',
#    'recordedDate': '2008-09-24T03:11:45-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'aaf73f7b-deb4-449e-a603-2db9997e3c69',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '195662009',
#       'display': 'Acute viral pharyngitis (disorder)'}],
#     'text': 'Acute viral pharyngitis (disorder)'},
#    'subject': {'reference': 'Patient/beb1b2a4-9198-462f-ae9d-972f173bd2b1'},
#    'encounter': {'reference': 'Encounter/4ed3cf39-017f-4b59-9d29-38fa0ac38176'},
#    'onsetDateTime': '2015-03-07T02:11:45-05:00',
#    'abatementDateTime': '2015-03-20T03:11:45-04:00',
#    'recordedDate': '2015-03-07T02:11:45-05:00'},
#   {'resourceType': 'Condition',
#    'id': '0975e382-4d4f-4e1c-8b5f-2dd5ad4ff46b',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '444814009',
#       'display': 'Viral sinusitis (disorder)'}],
#     'text': 'Viral sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/beb1b2a4-9198-462f-ae9d-972f173bd2b1'},
#    'encounter': {'reference': 'Encounter/4ad7623d-b76c-4d89-8d20-febfd5415f95'},
#    'onsetDateTime': '2017-11-08T02:11:45-05:00',
#    'abatementDateTime': '2017-11-22T02:11:45-05:00',
#    'recordedDate': '2017-11-08T02:11:45-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'cc62c5e5-435a-4746-8c09-e303ab28e4e8',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '19169002',
#       'display': 'Miscarriage in first trimester'}],
#     'text': 'Miscarriage in first trimester'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/81b9d21c-736a-4f17-8ca2-1801130bef19'},
#    'onsetDateTime': '1992-03-01T15:06:56-05:00',
#    'recordedDate': '1992-03-01T15:06:56-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'a8a131f4-4f53-457c-b132-9b9cf3f78713',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '79586000',
#       'display': 'Tubal pregnancy'}],
#     'text': 'Tubal pregnancy'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/c03ce773-0419-40c2-a902-902bdab6962c'},
#    'onsetDateTime': '1995-09-03T16:06:56-04:00',
#    'recordedDate': '1995-09-03T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': '813f8385-0c10-4e96-96d8-665f68f7a33b',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '162864005',
#       'display': 'Body mass index 30+ - obesity (finding)'}],
#     'text': 'Body mass index 30+ - obesity (finding)'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/20512714-03aa-4636-bb64-eba8616043d8'},
#    'onsetDateTime': '2012-03-25T16:06:56-04:00',
#    'recordedDate': '2012-03-25T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'e8e1bc3c-3d01-4fcb-91ad-dd1283611467',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '15777000',
#       'display': 'Prediabetes'}],
#     'text': 'Prediabetes'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/4100b52b-a0f8-4fe5-acca-77870e604a7c'},
#    'onsetDateTime': '2014-03-30T16:06:56-04:00',
#    'recordedDate': '2014-03-30T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': '8107823a-7414-4987-bb1f-1b24ad9e1b7d',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '263102004',
#       'display': 'Fracture subluxation of wrist'}],
#     'text': 'Fracture subluxation of wrist'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/dbd99c64-a98f-4d26-a532-1daa2c73fd56'},
#    'onsetDateTime': '2016-05-10T16:06:56-04:00',
#    'abatementDateTime': '2016-07-09T16:06:56-04:00',
#    'recordedDate': '2016-05-10T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'a6f711fa-0e4b-4802-9dc3-616225a9b1d1',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '39848009',
#       'display': 'Whiplash injury to neck'}],
#     'text': 'Whiplash injury to neck'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/7f9dddc4-6ab8-4a3e-86d2-47d8ed8d4df4'},
#    'onsetDateTime': '2017-06-04T16:06:56-04:00',
#    'abatementDateTime': '2017-06-25T16:06:56-04:00',
#    'recordedDate': '2017-06-04T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': '08eb4eda-de9f-4b2f-b646-d617bd32e276',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '301011002',
#       'display': 'Escherichia coli urinary tract infection'}],
#     'text': 'Escherichia coli urinary tract infection'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/06fbd047-8605-4acd-b3b3-e77548745be3'},
#    'onsetDateTime': '2020-03-02T15:06:56-05:00',
#    'abatementDateTime': '2020-04-05T16:06:56-04:00',
#    'recordedDate': '2020-03-02T15:06:56-05:00'},
#   {'resourceType': 'Condition',
#    'id': '0472d755-c7a7-4a32-9de1-633ec46257fb',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '271737000',
#       'display': 'Anemia (disorder)'}],
#     'text': 'Anemia (disorder)'},
#    'subject': {'reference': 'Patient/fdedcde9-3aa5-411f-bbdc-85052ec4ef7f'},
#    'encounter': {'reference': 'Encounter/d3adb89e-5bf6-46a3-8f7e-e173a54ca547'},
#    'onsetDateTime': '2020-03-15T16:06:56-04:00',
#    'recordedDate': '2020-03-15T16:06:56-04:00'},
#   {'resourceType': 'Condition',
#    'id': '03baad06-5cc2-43b2-b4fb-9ee7b67a8031',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '10509002',
#       'display': 'Acute bronchitis (disorder)'}],
#     'text': 'Acute bronchitis (disorder)'},
#    'subject': {'reference': 'Patient/588675dc-e80e-4528-a78f-af10f9755f23'},
#    'encounter': {'reference': 'Encounter/5caa998e-6ac5-4c48-a31a-389e49e9e2af'},
#    'onsetDateTime': '2017-02-26T14:48:04-05:00',
#    'abatementDateTime': '2017-03-12T15:48:04-04:00',
#    'recordedDate': '2017-02-26T14:48:04-05:00'},
#   {'resourceType': 'Condition',
#    'id': '1d721fc9-593b-4c94-bb71-3c1bbcdf59a8',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '70704007',
#       'display': 'Sprain of wrist'}],
#     'text': 'Sprain of wrist'},
#    'subject': {'reference': 'Patient/588675dc-e80e-4528-a78f-af10f9755f23'},
#    'encounter': {'reference': 'Encounter/cc4310d2-2bd4-4742-8ec5-a9b333e192ea'},
#    'onsetDateTime': '2017-11-22T14:48:04-05:00',
#    'abatementDateTime': '2017-12-06T14:48:04-05:00',
#    'recordedDate': '2017-11-22T14:48:04-05:00'},
#   {'resourceType': 'Condition',
#    'id': 'f7fb80d6-0f66-4b11-ad34-9796f80d069d',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'resolved'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '444814009',
#       'display': 'Viral sinusitis (disorder)'}],
#     'text': 'Viral sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/588675dc-e80e-4528-a78f-af10f9755f23'},
#    'encounter': {'reference': 'Encounter/a4920ae2-746b-412e-981f-ab77c1e0a15a'},
#    'onsetDateTime': '2018-02-26T14:48:04-05:00',
#    'abatementDateTime': '2018-03-12T15:48:04-04:00',
#    'recordedDate': '2018-02-26T14:48:04-05:00'},
#   {'resourceType': 'Condition',
#    'id': '99d5f4bd-7599-4f53-91ca-3da15606ed13',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '59621000',
#       'display': 'Hypertension'}],
#     'text': 'Hypertension'},
#    'subject': {'reference': 'Patient/7a05bc93-cf1a-4929-9aca-6178ba9abcb7'},
#    'encounter': {'reference': 'Encounter/f69b362f-db41-487d-865b-ae575b86c2bb'},
#    'onsetDateTime': '2007-03-30T19:03:08-04:00',
#    'recordedDate': '2007-03-30T19:03:08-04:00'},
#   {'resourceType': 'Condition',
#    'id': 'bf0bccff-5942-434b-a50f-20d72e38db50',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '40055000',
#       'display': 'Chronic sinusitis (disorder)'}],
#     'text': 'Chronic sinusitis (disorder)'},
#    'subject': {'reference': 'Patient/7a05bc93-cf1a-4929-9aca-6178ba9abcb7'},
#    'encounter': {'reference': 'Encounter/7bb8e70b-d458-456a-8198-cbcdeec5378c'},
#    'onsetDateTime': '2008-08-10T19:03:08-04:00',
#    'recordedDate': '2008-08-10T19:03:08-04:00'},
#   {'resourceType': 'Condition',
#    'id': '2ff4c070-9d29-4c2e-b1f3-e71a2bb2091d',
#    'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#       'code': 'active'}]},
#    'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#       'code': 'confirmed'}]},
#    'code': {'coding': [{'system': 'http://snomed.info/sct',
#       'code': '162864005',
#       'display': 'Body mass index 30+ - obesity (finding)'}],
#     'text': 'Body mass index 30+ - obesity (finding)'},
#    'subject': {'reference': 'Patient/7a05bc93-cf1a-4929-9aca-6178ba9abcb7'},
#    'encounter': {'reference': 'Encounter/c45393fa-7181-4439-b119-734dd458bb83'},
#    'onsetDateTime': '2010-04-16T19:03:08-04:00',
#    'recordedDate': '2010-04-16T19:03:08-04:00'},
#   {'resourceType': 'Condition',
#    'id': '90851f8b-d451-45c9-84e4-2bfa7652acc6',
# ...
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   {'resourceType': 'Patient',
#    'id': '5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7',
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.5.0-385-ge50db853\n .   Person seed: 2285782707199948145  Population seed: 1588766244164</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Allison Daugherty'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Boston',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 0},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 24}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': '5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': '5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-38-2795'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99917674'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X21226726X'}],
#    'name': [{'use': 'official',
#      'family': 'Schmeler',
#      'given': ['Wilfredo'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-971-6300', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1995-10-19',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.10981412077935},
#         {'url': 'longitude', 'valueDecimal': -72.37368303504032}]}],
#      'line': ['419 Wunsch Junction Suite 31'],
#      'city': 'Wilbraham',
#      'state': 'Massachusetts',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'S',
#       'display': 'Never Married'}],
#     'text': 'Never Married'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   {'resourceType': 'Patient',
#    'id': 'c1981741-f90e-4077-9156-429a3c4c5ded',
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.5.0-385-ge50db853\n .   Person seed: -791285276772638963  Population seed: 1588766244164</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Antoinette Parker'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Mansfield',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 0.38733474451210115},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 62.6126652554879}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'c1981741-f90e-4077-9156-429a3c4c5ded'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': 'c1981741-f90e-4077-9156-429a3c4c5ded'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-53-6258'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99916122'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X36388686X'}],
#    'name': [{'use': 'official',
#      'family': 'Lubowitz',
#      'given': ['Wilson'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-328-5229', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1956-05-06',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 41.99462996080205},
#         {'url': 'longitude', 'valueDecimal': -70.72871141309587}]}],
#      'line': ['741 Kunze Skyway'],
#      'city': 'Duxbury',
#      'state': 'Massachusetts',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'M'}],
#     'text': 'M'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   {'resourceType': 'Patient',
#    'id': 'f98b23bf-4443-46d0-9eaf-563e767cf948',
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.5.0-385-ge50db853\n .   Person seed: 531878887662525799  Population seed: 1588766244164</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Barbar Windler'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Randolph',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 5.476142773432209},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 47.52385722656779}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'f98b23bf-4443-46d0-9eaf-563e767cf948'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': 'f98b23bf-4443-46d0-9eaf-563e767cf948'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-31-4781'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99940524'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X57891834X'}],
#    'name': [{'use': 'official',
#      'family': 'Funk',
#      'given': ['Winston'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-497-7639', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1966-02-07',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.71109915561817},
#         {'url': 'longitude', 'valueDecimal': -71.1151630740751}]}],
#      'line': ['311 Kessler Trailer'],
#      'city': 'Haverhill',
#      'state': 'Massachusetts',
#      'postalCode': '01832',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'M',
#       'display': 'M'}],
#     'text': 'M'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   {'resourceType': 'Patient',
#    'id': 'c536dee9-9ef6-4807-ae20-9f1045c9c7d6',
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.5.0-385-ge50db853\n .   Person seed: -1475530382923179429  Population seed: 1588766244164</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Juli Johns'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Holyoke',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 0.7859494803031746},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 28.214050519696826}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'c536dee9-9ef6-4807-ae20-9f1045c9c7d6'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': 'c536dee9-9ef6-4807-ae20-9f1045c9c7d6'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-71-2777'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99913094'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X80761813X'}],
#    'name': [{'use': 'official',
#      'family': 'Bergstrom',
#      'given': ['Wm'],
#      'prefix': ['Mr.']}],
#    'telecom': [{'system': 'phone', 'value': '555-845-1730', 'use': 'home'}],
#    'gender': 'male',
#    'birthDate': '1990-11-18',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.719850443396766},
#         {'url': 'longitude', 'valueDecimal': -73.15928158793758}]}],
#      'line': ['891 Glover Throughway Unit 87'],
#      'city': 'North Adams',
#      'state': 'Massachusetts',
#      'postalCode': '01247',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'S',
#       'display': 'S'}],
#     'text': 'S'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]},
#   {'resourceType': 'Patient',
#    'id': 'a845ead4-d9de-42eb-b4b5-eb21a8963578',
#    'text': {'status': 'generated',
#     'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.5.0-385-ge50db853\n .   Person seed: 1870276488210015008  Population seed: 1588766244164</div>'},
#    'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#      'valueString': 'Lanie Hyatt'},
#     {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace',
#      'valueAddress': {'city': 'Millis',
#       'state': 'Massachusetts',
#       'country': 'US'}},
#     {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years',
#      'valueDecimal': 1.5908982035928143},
#     {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years',
#      'valueDecimal': 49.409101796407185}],
#    'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#      'value': 'a845ead4-d9de-42eb-b4b5-eb21a8963578'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'MR',
#         'display': 'Medical Record Number'}],
#       'text': 'Medical Record Number'},
#      'system': 'http://hospital.smarthealthit.org',
#      'value': 'a845ead4-d9de-42eb-b4b5-eb21a8963578'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'SS',
#         'display': 'Social Security Number'}],
#       'text': 'Social Security Number'},
#      'system': 'http://hl7.org/fhir/sid/us-ssn',
#      'value': '999-57-3633'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'DL',
#         'display': "Driver's License"}],
#       'text': "Driver's License"},
#      'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#      'value': 'S99958454'},
#     {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#         'code': 'PPN',
#         'display': 'Passport Number'}],
#       'text': 'Passport Number'},
#      'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#      'value': 'X17800821X'}],
#    'name': [{'use': 'official',
#      'family': 'Pagac',
#      'given': ['Yi'],
#      'prefix': ['Ms.']}],
#    'telecom': [{'system': 'phone', 'value': '555-504-1379', 'use': 'home'}],
#    'gender': 'female',
#    'birthDate': '1968-04-20',
#    'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation',
#        'extension': [{'url': 'latitude', 'valueDecimal': 42.05224964011243},
#         {'url': 'longitude', 'valueDecimal': -72.29730507616054}]}],
#      'line': ['1072 Waelchi Lane Apt 91'],
#      'city': 'Monson',
#      'state': 'Massachusetts',
#      'country': 'US'}],
#    'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus',
#       'code': 'S',
#       'display': 'S'}],
#     'text': 'S'},
#    'multipleBirthBoolean': False,
#    'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47',
#         'code': 'en-US',
#         'display': 'English'}],
#       'text': 'English'}}]}]}

# %%
# Finally, let's convert these into DataFrames
import pandas as pd

resource_dfs = {}

for resource_type, resources in resources_by_type.items():
    resource_dfs[resource_type] = pd.json_normalize(resources)

# Now we can work with them by type:

resource_dfs['Patient']
# Out:
#    resourceType                                    id  \
# 0       Patient  6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# 1       Patient  58c297c4-d684-4677-8024-01131d93835e
# 2       Patient  538a9a4e-8437-47d3-8c01-1a17dca8f0be
# 3       Patient  c6c60742-8694-46e4-bb42-b00bf6d8b536
# 4       Patient  fbfec681-d357-4b28-b1d2-5db6434c7846
# ..          ...                                   ...
# 95      Patient  5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7
# 96      Patient  c1981741-f90e-4077-9156-429a3c4c5ded
# 97      Patient  f98b23bf-4443-46d0-9eaf-563e767cf948
# 98      Patient  c536dee9-9ef6-4807-ae20-9f1045c9c7d6
# 99      Patient  a845ead4-d9de-42eb-b4b5-eb21a8963578
#
#                                             extension  \
# 0   [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 1   [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 2   [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 3   [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 4   [{'url': 'http://hl7.org/fhir/StructureDefinit...
# ..                                                ...
# 95  [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 96  [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 97  [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 98  [{'url': 'http://hl7.org/fhir/StructureDefinit...
# 99  [{'url': 'http://hl7.org/fhir/StructureDefinit...
#
#                                            identifier  \
# 0   [{'system': 'https://github.com/synthetichealt...
# 1   [{'system': 'https://github.com/synthetichealt...
# 2   [{'system': 'https://github.com/synthetichealt...
# 3   [{'system': 'https://github.com/synthetichealt...
# 4   [{'system': 'https://github.com/synthetichealt...
# ..                                                ...
# 95  [{'system': 'https://github.com/synthetichealt...
# 96  [{'system': 'https://github.com/synthetichealt...
# 97  [{'system': 'https://github.com/synthetichealt...
# 98  [{'system': 'https://github.com/synthetichealt...
# 99  [{'system': 'https://github.com/synthetichealt...
#
#                                                  name  \
# 0   [{'use': 'official', 'family': 'Lemke', 'given...
# 1   [{'use': 'official', 'family': 'Wintheiser', '...
# 2   [{'use': 'official', 'family': 'Alaniz', 'give...
# 3   [{'use': 'official', 'family': 'Walsh', 'given...
# 4   [{'use': 'official', 'family': 'Bednar', 'give...
# ..                                                ...
# 95  [{'use': 'official', 'family': 'Schmeler', 'gi...
# 96  [{'use': 'official', 'family': 'Lubowitz', 'gi...
# 97  [{'use': 'official', 'family': 'Funk', 'given'...
# 98  [{'use': 'official', 'family': 'Bergstrom', 'g...
# 99  [{'use': 'official', 'family': 'Pagac', 'given...
#
#                                               telecom  gender   birthDate  \
# 0   [{'system': 'phone', 'value': '555-532-1156', ...    male  1965-01-13
# 1   [{'system': 'phone', 'value': '555-712-4709', ...  female  1971-04-05
# 2   [{'system': 'phone', 'value': '555-446-6900', ...    male  1923-03-24
# 3   [{'system': 'phone', 'value': '555-436-4287', ...  female  1965-10-27
# 4   [{'system': 'phone', 'value': '555-405-4909', ...  female  1942-07-04
# ..                                                ...     ...         ...
# 95  [{'system': 'phone', 'value': '555-971-6300', ...    male  1995-10-19
# 96  [{'system': 'phone', 'value': '555-328-5229', ...    male  1956-05-06
# 97  [{'system': 'phone', 'value': '555-497-7639', ...    male  1966-02-07
# 98  [{'system': 'phone', 'value': '555-845-1730', ...    male  1990-11-18
# 99  [{'system': 'phone', 'value': '555-504-1379', ...  female  1968-04-20
#
#                                               address multipleBirthBoolean  \
# 0   [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 1   [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 2   [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 3   [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 4   [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# ..                                                ...                  ...
# 95  [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 96  [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 97  [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 98  [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
# 99  [{'extension': [{'url': 'http://hl7.org/fhir/S...                False
#
#                                         communication text.status  \
# 0   [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 1   [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 2   [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 3   [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 4   [{'language': {'coding': [{'system': 'urn:ietf...   generated
# ..                                                ...         ...
# 95  [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 96  [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 97  [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 98  [{'language': {'coding': [{'system': 'urn:ietf...   generated
# 99  [{'language': {'coding': [{'system': 'urn:ietf...   generated
#
#                                              text.div  \
# 0   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 1   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 2   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 3   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 4   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# ..                                                ...
# 95  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 96  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 97  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 98  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 99  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
#
#                                  maritalStatus.coding maritalStatus.text  \
# 0   [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 1   [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 2   [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 3   [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 4   [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# ..                                                ...                ...
# 95  [{'system': 'http://terminology.hl7.org/CodeSy...      Never Married
# 96  [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 97  [{'system': 'http://terminology.hl7.org/CodeSy...                  M
# 98  [{'system': 'http://terminology.hl7.org/CodeSy...                  S
# 99  [{'system': 'http://terminology.hl7.org/CodeSy...                  S
#
#     multipleBirthInteger
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 95                   NaN
# 96                   NaN
# 97                   NaN
# 98                   NaN
# 99                   NaN
#
# [100 rows x 16 columns]

# %%
# Note that there's no perfect option for representing FHIR in a tabular way, because of all the nested values,
# but we can do a little better with the flatten_json library: https://github.com/amirziai/flatten

from flatten_json import flatten

for resource_type, resources in resources_by_type.items():
    resource_dfs[resource_type] = pd.json_normalize(list(map(lambda r: flatten(r), resources)))

# Now let's take another look
resource_dfs['Patient']
# Out:
#    resourceType                                    id text_status  \
# 0       Patient  6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2   generated
# 1       Patient  58c297c4-d684-4677-8024-01131d93835e   generated
# 2       Patient  538a9a4e-8437-47d3-8c01-1a17dca8f0be   generated
# 3       Patient  c6c60742-8694-46e4-bb42-b00bf6d8b536   generated
# 4       Patient  fbfec681-d357-4b28-b1d2-5db6434c7846   generated
# ..          ...                                   ...         ...
# 95      Patient  5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7   generated
# 96      Patient  c1981741-f90e-4077-9156-429a3c4c5ded   generated
# 97      Patient  f98b23bf-4443-46d0-9eaf-563e767cf948   generated
# 98      Patient  c536dee9-9ef6-4807-ae20-9f1045c9c7d6   generated
# 99      Patient  a845ead4-d9de-42eb-b4b5-eb21a8963578   generated
#
#                                              text_div  \
# 0   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 1   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 2   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 3   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 4   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# ..                                                ...
# 95  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 96  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 97  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 98  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 99  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
#
#                                       extension_0_url extension_0_valueString  \
# 0   http://hl7.org/fhir/StructureDefinition/patien...            Lettie Boyle
# 1   http://hl7.org/fhir/StructureDefinition/patien...   Marquetta Schamberger
# 2   http://hl7.org/fhir/StructureDefinition/patien...              Pilar Orta
# 3   http://hl7.org/fhir/StructureDefinition/patien...            Arvilla Haag
# 4   http://hl7.org/fhir/StructureDefinition/patien...        Marcelina Harber
# ..                                                ...                     ...
# 95  http://hl7.org/fhir/StructureDefinition/patien...       Allison Daugherty
# 96  http://hl7.org/fhir/StructureDefinition/patien...       Antoinette Parker
# 97  http://hl7.org/fhir/StructureDefinition/patien...          Barbar Windler
# 98  http://hl7.org/fhir/StructureDefinition/patien...              Juli Johns
# 99  http://hl7.org/fhir/StructureDefinition/patien...             Lanie Hyatt
#
#                                       extension_1_url  \
# 0   http://hl7.org/fhir/StructureDefinition/patien...
# 1   http://hl7.org/fhir/StructureDefinition/patien...
# 2   http://hl7.org/fhir/StructureDefinition/patien...
# 3   http://hl7.org/fhir/StructureDefinition/patien...
# 4   http://hl7.org/fhir/StructureDefinition/patien...
# ..                                                ...
# 95  http://hl7.org/fhir/StructureDefinition/patien...
# 96  http://hl7.org/fhir/StructureDefinition/patien...
# 97  http://hl7.org/fhir/StructureDefinition/patien...
# 98  http://hl7.org/fhir/StructureDefinition/patien...
# 99  http://hl7.org/fhir/StructureDefinition/patien...
#
#    extension_1_valueAddress_city  \
# 0                         Boston
# 1                          Macau
# 2                       San Jose
# 3                         Norton
# 4                       Brockton
# ..                           ...
# 95                        Boston
# 96                     Mansfield
# 97                      Randolph
# 98                       Holyoke
# 99                        Millis
#
#                        extension_1_valueAddress_state  \
# 0                                       Massachusetts
# 1   Macao Special Administrative Region of the Peo...
# 2                                            San Jose
# 3                                       Massachusetts
# 4                                       Massachusetts
# ..                                                ...
# 95                                      Massachusetts
# 96                                      Massachusetts
# 97                                      Massachusetts
# 98                                      Massachusetts
# 99                                      Massachusetts
#
#    extension_1_valueAddress_country  ... multipleBirthBoolean  \
# 0                                US  ...                False
# 1                                CN  ...                False
# 2                                CR  ...                False
# 3                                US  ...                False
# 4                                US  ...                False
# ..                              ...  ...                  ...
# 95                               US  ...                False
# 96                               US  ...                False
# 97                               US  ...                False
# 98                               US  ...                False
# 99                               US  ...                False
#
#     communication_0_language_coding_0_system  \
# 0                            urn:ietf:bcp:47
# 1                            urn:ietf:bcp:47
# 2                            urn:ietf:bcp:47
# 3                            urn:ietf:bcp:47
# 4                            urn:ietf:bcp:47
# ..                                       ...
# 95                           urn:ietf:bcp:47
# 96                           urn:ietf:bcp:47
# 97                           urn:ietf:bcp:47
# 98                           urn:ietf:bcp:47
# 99                           urn:ietf:bcp:47
#
#    communication_0_language_coding_0_code  \
# 0                                   en-US
# 1                                      zh
# 2                                      es
# 3                                   en-US
# 4                                   en-US
# ..                                    ...
# 95                                  en-US
# 96                                  en-US
# 97                                  en-US
# 98                                  en-US
# 99                                  en-US
#
#     communication_0_language_coding_0_display communication_0_language_text  \
# 0                                     English                       English
# 1                                     Chinese                       Chinese
# 2                                     Spanish                       Spanish
# 3                                     English                       English
# 4                                     English                       English
# ..                                        ...                           ...
# 95                                    English                       English
# 96                                    English                       English
# 97                                    English                       English
# 98                                    English                       English
# 99                                    English                       English
#
#    name_1_use name_1_family name_1_given_0 name_1_prefix_0  \
# 0         NaN           NaN            NaN             NaN
# 1      maiden     Heathcote          Aleta            Mrs.
# 2         NaN           NaN            NaN             NaN
# 3      maiden        Kuphal          Alyce            Mrs.
# 4      maiden    Runolfsson        Arnette            Mrs.
# ..        ...           ...            ...             ...
# 95        NaN           NaN            NaN             NaN
# 96        NaN           NaN            NaN             NaN
# 97        NaN           NaN            NaN             NaN
# 98        NaN           NaN            NaN             NaN
# 99        NaN           NaN            NaN             NaN
#
#    multipleBirthInteger
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 95                  NaN
# 96                  NaN
# 97                  NaN
# 98                  NaN
# 99                  NaN
#
# [100 rows x 73 columns]

# %%
# Next, what if we know in advance we will only want certain fields? 

# https://github.com/beda-software/fhirpath-py

import fhirpathpy

fhir_paths=[
        ["id", "identifier[0].value"],
        ["gender", "gender"],
        ["date_of_birth", "birthDate"],
        ["marital_status", "maritalStatus.coding[0].code"]
    ]

for f in fhir_paths:
     f[1] = fhirpathpy.compile(f[1])

for resource_type, resources in resources_by_type.items():
    filtered_resources = []
    
    for resource in resources:
        filtered_resource = {}
        for f in fhir_paths:
            fieldname = f[0]
            func = f[1]
            filtered_resource[fieldname] = func(resource)
            
            if isinstance(filtered_resource[fieldname], list) and len(filtered_resource[fieldname]) == 1:
                filtered_resource[fieldname] = filtered_resource[fieldname][0]
            
        filtered_resources.append(filtered_resource)

    resource_dfs[resource_type] = pd.json_normalize(list(map(lambda r: flatten(r), filtered_resources)))
    

resource_dfs['Patient']
# Out:
#                                       id  gender date_of_birth marital_status
# 0   6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2    male    1965-01-13              M
# 1   58c297c4-d684-4677-8024-01131d93835e  female    1971-04-05              M
# 2   538a9a4e-8437-47d3-8c01-1a17dca8f0be    male    1923-03-24              M
# 3   c6c60742-8694-46e4-bb42-b00bf6d8b536  female    1965-10-27              M
# 4   fbfec681-d357-4b28-b1d2-5db6434c7846  female    1942-07-04              M
# ..                                   ...     ...           ...            ...
# 95  5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7    male    1995-10-19              S
# 96  c1981741-f90e-4077-9156-429a3c4c5ded    male    1956-05-06              M
# 97  f98b23bf-4443-46d0-9eaf-563e767cf948    male    1966-02-07              M
# 98  c536dee9-9ef6-4807-ae20-9f1045c9c7d6    male    1990-11-18              S
# 99  a845ead4-d9de-42eb-b4b5-eb21a8963578  female    1968-04-20              S
#
# [100 rows x 4 columns]

# %%
# Now we have everything we need. Let's bring everything together into one class with a clear entrypoint

import requests
import jwt
import datetime
import json
import fhirpathpy
from flatten_json import flatten



class BulkDataFetcher:
    def __init__(
        self,
        base_url: str,
        client_id: str,
        private_key: str,
        key_id: str,
        session = None
    ):
        self.base_url = base_url
        self.client_id = client_id
        self.private_key = private_key
        self.key_id = key_id
        
        self.token = None
        self.token_expire_time = None
        
        if session is None:
            self.session = requests.Session()
        else:
            self.session = session
            
        r = self.session.get(f'{base_url}/.well-known/smart-configuration')
        smart_config = r.json()
        self.token_endpoint = smart_config['token_endpoint']
        
        self.resource_types = []
        self.fhir_paths = {}
        
        
    def get_token(self):
        if self.token and datetime.datetime.now() < self.expire_time:
            # the existing token is still valid so 
            return self.token

        assertion = jwt.encode({
                'iss': self.client_id,
                'sub': self.client_id,
                'aud': self.token_endpoint,
                'exp': int((datetime.datetime.now() + datetime.timedelta(minutes=5)).timestamp())
        }, self.private_key, algorithm='RS384',
        headers={"kid": key_id})

        r = self.session.post(self.token_endpoint, data={
            'scope': 'system/*.read',
            'grant_type': 'client_credentials',
            'client_assertion_type': 'urn:ietf:params:oauth:client-assertion-type:jwt-bearer',
            'client_assertion': assertion
        })

        token_response = r.json()
        self.token = token_response['access_token']
        self.expire_time = datetime.datetime.now() + datetime.timedelta(seconds=token_response['expires_in'])

        return self.token
    
    def add_resource_type(self, resource_type: str, fhir_paths = None):
        self.resource_types.append(resource_type)
        if fhir_paths:
            # fhir_paths=[
            #    ("id", "identifier[0].value"),
            #    ("marital_status", "maritalStatus.coding[0].code")
            # ]
            compiled_fhir_paths = [(f[0], fhirpathpy.compile(f[1])) for f in fhir_paths]
            self.fhir_paths[resource_type] = compiled_fhir_paths
            
    def _invoke_request(self):
        types = ','.join(self.resource_types)
        r = self.session.get(f'{self.base_url}/Patient/$export?_type={types}', headers={'Authorization': f'Bearer {self.get_token()}', 'Accept': 'application/fhir+json', 'Prefer': 'respond-async'})

        self.check_url = r.headers['Content-Location']
        return self.check_url
    
    def _wait_until_ready(self):
        while True:
            r = self.session.get(self.check_url, headers={'Authorization': f'Bearer {self.get_token()}', 'Accept': 'application/fhir+json'})

            # There are three possible options here: http://hl7.org/fhir/uv/bulkdata/export.html#bulk-data-status-request
            # Error = 4xx or 5xx status code
            # In-Progress = 202
            # Complete = 200

            if r.status_code == 200:
                # complete
                response = r.json()
                self.output_files = response['output']
                return self.output_files

            elif r.status_code == 202:
                # in progress
                delay = r.headers['Retry-After']

                sleep(int(delay))

            else:
                raise RuntimeError(r.text)

    def get_dataframe(self):
        self._invoke_request()
        self._wait_until_ready()
        
        resources_by_type = {}

        for output_file in self.output_files:
            download_url = output_file['url']
            resource_type = output_file['type']

            r = self.session.get(download_url, headers={'Authorization': f'Bearer {get_token()}', 'Accept': 'application/fhir+json'})

            ndjson = r.text.strip()

            if resource_type not in resources_by_type:
                resources_by_type[resource_type] = []

            for line in ndjson.split('\n'):
                resource = json.loads(line)
                
                if resource_type in self.fhir_paths:
                    fhir_paths = self.fhir_paths[resource_type]
                    filtered_resource = {}
                    for f in fhir_paths:
                        fieldname = f[0]
                        func = f[1]
                        filtered_resource[fieldname] = func(resource)

                        if isinstance(filtered_resource[fieldname], list) and len(filtered_resource[fieldname]) == 1:
                            filtered_resource[fieldname] = filtered_resource[fieldname][0]
                    resource = filtered_resource

                resources_by_type[resource_type].append(resource)
        
        dfs = {}
        
        for resource_type, resources in resources_by_type.items():
            dfs[resource_type] = pd.json_normalize(list(map(lambda r: flatten(r), resources)))
        
        return dfs


# And then to invoke it:


fetcher = BulkDataFetcher(server_url, client_id, private_key, key_id, session)                

fetcher.add_resource_type('Patient', [
        ("id", "identifier[0].value"),
        ("gender", "gender"),
        ("date_of_birth", "birthDate"),
        ("marital_status", "maritalStatus.coding[0].code")
])

fetcher.add_resource_type('Condition')

dfs = fetcher.get_dataframe()

dfs['Patient']
# Out:
#                                       id  gender date_of_birth marital_status
# 0   6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2    male    1965-01-13              M
# 1   58c297c4-d684-4677-8024-01131d93835e  female    1971-04-05              M
# 2   538a9a4e-8437-47d3-8c01-1a17dca8f0be    male    1923-03-24              M
# 3   c6c60742-8694-46e4-bb42-b00bf6d8b536  female    1965-10-27              M
# 4   fbfec681-d357-4b28-b1d2-5db6434c7846  female    1942-07-04              M
# ..                                   ...     ...           ...            ...
# 95  5efb1ac1-d29b-40a5-a3d1-2d682f10bfa7    male    1995-10-19              S
# 96  c1981741-f90e-4077-9156-429a3c4c5ded    male    1956-05-06              M
# 97  f98b23bf-4443-46d0-9eaf-563e767cf948    male    1966-02-07              M
# 98  c536dee9-9ef6-4807-ae20-9f1045c9c7d6    male    1990-11-18              S
# 99  a845ead4-d9de-42eb-b4b5-eb21a8963578  female    1968-04-20              S
#
# [100 rows x 4 columns]

# %%
dfs['Condition']
# Out:
#     resourceType                                    id  \
# 0      Condition  a5a38601-b6fe-46b4-a67e-cde9d5957dde
# 1      Condition  8f818ad4-c292-47e8-8d99-c4c54174b671
# 2      Condition  65d9d5f2-a772-4586-932f-df1f2ce1a863
# 3      Condition  77ac8342-6950-4302-a303-efba12e06785
# 4      Condition  6514ab0c-bc64-4e1b-aa61-b97d27d72bc7
# ..           ...                                   ...
# 634    Condition  ab051f6c-4298-407b-9315-2322ce913539
# 635    Condition  76c1f07a-f8f2-4705-aa80-5f7a25d7c651
# 636    Condition  b9a078eb-bb83-49ed-b4ed-633d1445356d
# 637    Condition  0fe427ce-7ea1-4409-8de1-3879f9dc56bb
# 638    Condition  88f3f41a-68ec-46dd-8d44-9178d3872220
#
#                         clinicalStatus_coding_0_system  \
# 0    http://terminology.hl7.org/CodeSystem/conditio...
# 1    http://terminology.hl7.org/CodeSystem/conditio...
# 2    http://terminology.hl7.org/CodeSystem/conditio...
# 3    http://terminology.hl7.org/CodeSystem/conditio...
# 4    http://terminology.hl7.org/CodeSystem/conditio...
# ..                                                 ...
# 634  http://terminology.hl7.org/CodeSystem/conditio...
# 635  http://terminology.hl7.org/CodeSystem/conditio...
# 636  http://terminology.hl7.org/CodeSystem/conditio...
# 637  http://terminology.hl7.org/CodeSystem/conditio...
# 638  http://terminology.hl7.org/CodeSystem/conditio...
#
#     clinicalStatus_coding_0_code  \
# 0                         active
# 1                         active
# 2                         active
# 3                       resolved
# 4                         active
# ..                           ...
# 634                       active
# 635                     resolved
# 636                     resolved
# 637                     resolved
# 638                     resolved
#
#                     verificationStatus_coding_0_system  \
# 0    http://terminology.hl7.org/CodeSystem/conditio...
# 1    http://terminology.hl7.org/CodeSystem/conditio...
# 2    http://terminology.hl7.org/CodeSystem/conditio...
# 3    http://terminology.hl7.org/CodeSystem/conditio...
# 4    http://terminology.hl7.org/CodeSystem/conditio...
# ..                                                 ...
# 634  http://terminology.hl7.org/CodeSystem/conditio...
# 635  http://terminology.hl7.org/CodeSystem/conditio...
# 636  http://terminology.hl7.org/CodeSystem/conditio...
# 637  http://terminology.hl7.org/CodeSystem/conditio...
# 638  http://terminology.hl7.org/CodeSystem/conditio...
#
#     verificationStatus_coding_0_code    code_coding_0_system  \
# 0                          confirmed  http://snomed.info/sct
# 1                          confirmed  http://snomed.info/sct
# 2                          confirmed  http://snomed.info/sct
# 3                          confirmed  http://snomed.info/sct
# 4                          confirmed  http://snomed.info/sct
# ..                               ...                     ...
# 634                        confirmed  http://snomed.info/sct
# 635                        confirmed  http://snomed.info/sct
# 636                        confirmed  http://snomed.info/sct
# 637                        confirmed  http://snomed.info/sct
# 638                        confirmed  http://snomed.info/sct
#
#     code_coding_0_code                    code_coding_0_display  \
# 0             40055000             Chronic sinusitis (disorder)
# 1            162864005  Body mass index 30+ - obesity (finding)
# 2             15777000                              Prediabetes
# 3             68496003                           Polyp of colon
# 4            271737000                        Anemia (disorder)
# ..                 ...                                      ...
# 634          162864005  Body mass index 30+ - obesity (finding)
# 635           39848009                  Whiplash injury to neck
# 636           70704007                          Sprain of wrist
# 637          444814009               Viral sinusitis (disorder)
# 638           72892002                         Normal pregnancy
#
#                                    code_text  \
# 0               Chronic sinusitis (disorder)
# 1    Body mass index 30+ - obesity (finding)
# 2                                Prediabetes
# 3                             Polyp of colon
# 4                          Anemia (disorder)
# ..                                       ...
# 634  Body mass index 30+ - obesity (finding)
# 635                  Whiplash injury to neck
# 636                          Sprain of wrist
# 637               Viral sinusitis (disorder)
# 638                         Normal pregnancy
#
#                                 subject_reference  \
# 0    Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# 1    Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# 2    Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# 3    Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# 4    Patient/6c5d9ca9-54d7-42f5-bfae-a7c19cd217f2
# ..                                            ...
# 634  Patient/a845ead4-d9de-42eb-b4b5-eb21a8963578
# 635  Patient/a845ead4-d9de-42eb-b4b5-eb21a8963578
# 636  Patient/a845ead4-d9de-42eb-b4b5-eb21a8963578
# 637  Patient/a845ead4-d9de-42eb-b4b5-eb21a8963578
# 638  Patient/a845ead4-d9de-42eb-b4b5-eb21a8963578
#
#                                 encounter_reference  \
# 0    Encounter/17b801ac-58e3-4f6b-8b48-8e33f3a36086
# 1    Encounter/0953dd44-90bb-4805-badd-169a761a6ab3
# 2    Encounter/d4e1370a-a679-4570-a3dc-e4f7ac847512
# 3    Encounter/58ad433b-3707-4d40-9b63-2a803b4913bd
# 4    Encounter/58ad433b-3707-4d40-9b63-2a803b4913bd
# ..                                              ...
# 634  Encounter/c5ed8aed-2b7e-4630-bd1d-ac5090967edc
# 635  Encounter/9c8b41dd-d6fd-4691-ae46-01b47992dd8d
# 636  Encounter/f044f05a-8433-4952-926d-dd8e2b4ee44e
# 637  Encounter/9100e9aa-1206-403b-b2bf-b75ac23991bd
# 638  Encounter/2d975caf-e6bf-43c2-8778-ea293df1f255
#
#                  onsetDateTime               recordedDate  \
# 0    1985-06-18T17:30:49-04:00  1985-06-18T17:30:49-04:00
# 1    2005-01-19T16:30:49-05:00  2005-01-19T16:30:49-05:00
# 2    2013-02-06T16:30:49-05:00  2013-02-06T16:30:49-05:00
# 3    2015-01-14T16:30:49-05:00  2015-01-14T16:30:49-05:00
# 4    2015-01-14T16:30:49-05:00  2015-01-14T16:30:49-05:00
# ..                         ...                        ...
# 634  2014-11-22T15:43:42-05:00  2014-11-22T15:43:42-05:00
# 635  2015-07-13T16:43:42-04:00  2015-07-13T16:43:42-04:00
# 636  2018-07-25T16:43:42-04:00  2018-07-25T16:43:42-04:00
# 637  2018-09-26T16:43:42-04:00  2018-09-26T16:43:42-04:00
# 638  2018-12-22T15:43:42-05:00  2018-12-22T15:43:42-05:00
#
#              abatementDateTime
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3    2017-05-03T17:30:49-04:00
# 4                          NaN
# ..                         ...
# 634                        NaN
# 635  2015-08-10T16:43:42-04:00
# 636  2018-08-15T16:43:42-04:00
# 637  2018-10-17T16:43:42-04:00
# 638  2019-07-27T16:43:42-04:00
#
# [639 rows x 15 columns]
